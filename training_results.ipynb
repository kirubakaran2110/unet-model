# %%
import os
import cv2
import torch
import matplotlib.pyplot as plt
from glob import glob
from torchvision import transforms
from PIL import Image

# Load model
model = UNet()
model.load_state_dict(torch.load("checkpoints/unet_final.pth", map_location='cpu'))
model.eval()

# Define directories
image_dir = "data/images"
mask_dir = "data/masks"

# Get image and mask paths
image_paths = sorted(glob(os.path.join(image_dir, "im_*.png")))
mask_paths = sorted(glob(os.path.join(mask_dir, "m_*.png")))

# Function to visualize prediction
def show_prediction(image_path, mask_path):
    img = Image.open(image_path).convert("RGB")
    mask = Image.open(mask_path).convert("L")
    transform = transforms.ToTensor()
    img_t = transform(img).unsqueeze(0)

    with torch.no_grad():
        pred = torch.sigmoid(model(img_t))
        pred = (pred > 0.5).float().squeeze().numpy()

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Original Image")

    plt.subplot(1, 3, 2)
    plt.imshow(mask, cmap='gray')
    plt.title("Ground Truth Mask")

    plt.subplot(1, 3, 3)
    plt.imshow(pred, cmap='gray')
    plt.title("Predicted Mask")

    plt.show()

# Display a few predictions
for img, mask in zip(image_paths[:3], mask_paths[:3]):
    show_prediction(img, mask)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 11
#       9 # Load model
#      10 model = UNet()
# ---> 11 model.load_state_dict(torch.load("checkpoints/unet_final.pth", map_location='cpu'))
#      12 model.eval()
#      14 # Define directories
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:2624, in Module.load_state_dict(self, state_dict, strict, assign)
#    2616         error_msgs.insert(
#    2617             0,
#    2618             "Missing key(s) in state_dict: {}. ".format(
#    2619                 ", ".join(f'"{k}"' for k in missing_keys)
#    2620             ),
#    2621         )
#    2623 if len(error_msgs) > 0:
# -> 2624     raise RuntimeError(
#    2625         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2626             self.__class__.__name__, "\n\t".join(error_msgs)
# ...
